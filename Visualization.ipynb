# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import DataUtils

# %%
trainloader, testloader = DataUtils.get_dataloaders(32)

# %%
example = next(enumerate(trainloader))[1]

# %%
print(example[0].shape, example[1].shape)
# Out:
# torch.Size([32, 543, 27]) torch.Size([32, 543])

# %%
X_sample = example[0][0]
y_sample = example[1][0]

# %%
print(X_sample.shape, y_sample.shape)
# Out:
# torch.Size([543, 27]) torch.Size([543])

# %%
plt.title("RUL Sample")
plt.plot(y_sample)

# %%
for i in range(X_sample.shape[1]):
    plt.title("Feature " + str(i))
    plt.plot(X_sample[:,i])
    plt.show()

# %%
# These columns capture RUL or are constant (id, etc.)
columns_excluded = [0, 1, 26]
